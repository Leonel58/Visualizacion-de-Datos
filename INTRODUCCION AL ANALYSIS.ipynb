# %%
import pandas as pd

# %%
ruta = "C:\\Users\\WIN10\\Desktop\\MAESTRO EN VISUALIZACION DE DATOS\\08 - dataset.csv"

# %%
DATA = pd.read_csv(ruta, sep = ",", index_col = "id")
DATA.head(5)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
DATA.shape
# Out:
# (27, 9)

# %%
DATA.describe()
# Out:
#         favorites    retweets   mentions   followers    followees
# count   26.000000   26.000000  26.000000   26.000000    27.000000
# mean   280.538462   80.000000  15.423077  352.807692  1190.185185
# std    153.377242   40.303846   9.596554  375.319493  1965.735995
# min     23.000000   21.000000   1.000000   12.000000   129.000000
# 25%    139.250000   45.500000   8.250000   21.000000   258.000000
# 50%    305.500000   79.000000  16.000000  332.000000   351.000000
# 75%    422.500000  110.750000  23.500000  389.000000  1822.000000
# max    500.000000  146.000000  29.000000  982.000000  9918.000000

# %%
DATA.head(20)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
eliminar_nan = DATA.dropna()
eliminar_nan
# Out:
#                                                 full_text  favorites  \
# id
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# 183734                             I cannot believe this!       50.0
# 183735                             Buy this product NOW!!      418.0
# ...

# %%
data_fillna = DATA.fillna(5)
data_fillna
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        5.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
DATA.head(5)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
rellenar_col_conjunto = DATA.fillna({"retweets":100, "mentions":20})
rellenar_col_conjunto
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
DATA[["favorites"]]
# Out:
#         favorites
# id
# 183721       23.0
# 183722      500.0
# 183723      190.0
# 183724      131.0
# 183725      113.0
# 183726      492.0
# 183727      158.0
# 183728        NaN
# 183729      198.0
# 183730      272.0
# 183731       43.0
# 183732      349.0
# 183733      467.0
# 183734       50.0
# 183735      418.0
# 183736      361.0
# 183737      346.0
# 183738      296.0
# 183739      315.0
# 183740      133.0
# 183741       92.0
# 183742      255.0
# 183743      432.0
# 183744      430.0
# 183745      424.0
# 183746      488.0
# 183747      318.0

# %%
DATA.iloc[[0]]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258

# %%
DATA.iloc[0:5]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183723     123.0       6.0   MEXICO    pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR   galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO    pedrojuarez       12.0        129

# %%
DATA.head(100)
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
DATA.iloc[[1,5,10,20][:5]]
# Out:
#                                                 full_text  favorites  \
# id
# 183722                Today we commemorate and MNML Case.      500.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183741                            Programming? i love it!       92.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183722      21.0       NaN   BRASIL  mateusmartins      982.0       1822
# 183726      70.0       6.0   BRASIL  mateusmartins      982.0       1822
# 183731     111.0       8.0   BRASIL  mateusmartins      982.0       1822
# 183741     146.0       1.0  ECUADOR   galocastillo      332.0        378

# %%
DATA.loc[[183736,183745],["retweets","country","followees"]]
# Out:
#         retweets country  followees
# id
# 183736      92.0  MEXICO        129
# 183745     110.0  BRASIL        351

# %%
DATA.loc[[183731,183741],["favorites","mentions","followees"]]
# Out:
#         favorites  mentions  followees
# id
# 183731       43.0       8.0       1822
# 183741       92.0       1.0        378

# %%
DATA.columns
# Out:
# Index(['full_text', 'favorites', 'retweets', 'mentions', 'country', 'user',
#        'followers', 'followees'],
#       dtype='object')

# %%
DATA.iloc[1:20,:5]
# Out:
#                                                 full_text  favorites  \
# id
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# ...

# %%
DATA.shape
# Out:
# (27, 8)

# %%
DATA.columns
# Out:
# Index(['full_text', 'favorites', 'retweets', 'mentions', 'country', 'user',
#        'followers', 'followees'],
#       dtype='object')

# %%
DATA.iloc[:10,5:]
# Out:
#                  user  followers  followees
# id
# 183721  leonardokuffo      389.0        258
# 183722  mateusmartins      982.0       1822
# 183723    pedrojuarez       12.0        129
# 183724   galocastillo      332.0        378
# 183725    pedrojuarez       12.0        129
# 183726  mateusmartins      982.0       1822
# 183727  leonardokuffo      389.0        258
# 183728    pedrojuarez       12.0        129
# 183729    pedrojuarez       12.0        129
# 183730  mateusmartins      982.0       1822

# %%
DATA.columns
# Out:
# Index(['full_text', 'favorites', 'retweets', 'mentions', 'country', 'user',
#        'followers', 'followees'],
#       dtype='object')

# %%
DATA.iloc[20:25][["favorites","mentions"]]
# Out:
#         favorites  mentions
# id
# 183741       92.0       1.0
# 183742      255.0      17.0
# 183743      432.0      18.0
# 183744      430.0      28.0
# 183745      424.0      29.0

# %%
DATA.iloc[:20][["full_text","retweets","user"]]
# Out:
#                                                 full_text  retweets  \
# id
# 183721  Flying home to run down from the power to comi...       NaN
# 183722                Today we commemorate and MNML Case.      21.0
# 183723       Today we have reached US$6.55 Billion TT$44…     123.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      76.0
# 183725                                    Welcome back! 🙌     130.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      70.0
# 183727                                 80's & friends! ✈️      40.0
# 183728  Thank you guess how did I feel somewhat offend...      50.0
# 183729        OnePlus 8 international giveaway classifies      82.0
# 183730                Here it is.. Retweet this desperate      92.0
# 183731  Great to advertise during the year I tweeted a...     111.0
# 183732  Its been in love with the game with the origin...      44.0
# 183733                           Programming is the best!      69.0
# ...

# %%
DATA.iloc[10:25][["full_text"]]
# Out:
#                                                 full_text
# id
# 183731  Great to advertise during the year I tweeted a...
# 183732  Its been in love with the game with the origin...
# 183733                           Programming is the best!
# 183734                             I cannot believe this!
# 183735                             Buy this product NOW!!
# 183736  I have one is best color gradients: Just relea...
# 183737                                              PIC!!
# 183738                             hmmm feeling bad today
# 183739                          not feeling god right now
# 183740                        Programming is a hot topic!
# 183741                            Programming? i love it!
# 183742                                            WHAT???
# 183743                         Amazing video by Leonardo!
# 183744                                        Thanks man!
# 183745          There is nothing better than programming!

# %%
DATA.columns
# Out:
# Index(['full_text', 'favorites', 'retweets', 'mentions', 'country', 'user',
#        'followers', 'followees'],
#       dtype='object')

# %%
DATA.iloc[20:25,4:7]
# Out:
#         country          user  followers
# id
# 183741  ECUADOR  galocastillo      332.0
# 183742  ECUADOR  galocastillo      332.0
# 183743   BRASIL    lucasperes       82.0
# 183744   BRASIL    lucasperes        NaN
# 183745   BRASIL    lucasperes       82.0

# %%
USER = DATA.iloc[20:25,4:7]

# %%
USER
# Out:
#         country          user  followers
# id
# 183741  ECUADOR  galocastillo      332.0
# 183742  ECUADOR  galocastillo      332.0
# 183743   BRASIL    lucasperes       82.0
# 183744   BRASIL    lucasperes        NaN
# 183745   BRASIL    lucasperes       82.0

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.distplot(USER["followers"])
# Out:
# C:\Users\WIN10\AppData\Local\Temp\ipykernel_14792\853676653.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(USER["followers"])
# <Axes: xlabel='followers', ylabel='Density'>

# %%
sns.pairplot(USER)

# %%
DATA.iloc[:10]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
#
#         retweets  mentions  country           user  followers  followees
# id
# 183721       NaN      10.0  ECUADOR  leonardokuffo      389.0        258
# ...

# %%
DATA.iloc[[2,5,8,7]]
# Out:
#                                                 full_text  favorites  \
# id
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
#
#         retweets  mentions country           user  followers  followees
# id
# 183723     123.0       6.0  MEXICO    pedrojuarez       12.0        129
# 183726      70.0       6.0  BRASIL  mateusmartins      982.0       1822
# 183729      82.0      26.0  MEXICO    pedrojuarez       12.0        129
# 183728      50.0      10.0  MEXICO    pedrojuarez       12.0        129

# %%
DATA.loc[[183726,183729]]
# Out:
#                                                 full_text  favorites  \
# id
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183729        OnePlus 8 international giveaway classifies      198.0
#
#         retweets  mentions country           user  followers  followees
# id
# 183726      70.0       6.0  BRASIL  mateusmartins      982.0       1822
# 183729      82.0      26.0  MEXICO    pedrojuarez       12.0        129

# %%
DATA.loc[[183726,183729],["full_text","retweets","followers"]]
# Out:
#                                                 full_text  retweets  followers
# id
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      70.0      982.0
# 183729        OnePlus 8 international giveaway classifies      82.0       12.0

# %%
DATA.loc[[183721,183726,183731,183737],["full_text"]]
# Out:
#                                                 full_text
# id
# 183721  Flying home to run down from the power to comi...
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!
# 183731  Great to advertise during the year I tweeted a...
# 183737                                              PIC!!

# %%
DATA
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...

# %%
DATA.loc[[183735,183746,183732],["country"]]
# Out:
#        country
# id
# 183735  MEXICO
# 183746  MEXICO
# 183732  BRASIL

# %%
DATA.loc[[183744,183738]]
# Out:
#                      full_text  favorites  retweets  mentions country  \
# id
# 183744             Thanks man!      430.0     143.0      28.0  BRASIL
# 183738  hmmm feeling bad today      296.0      93.0      29.0  MEXICO
#
#                    user  followers  followees
# id
# 183744       lucasperes        NaN        351
# 183738  gabrielcarvajal       21.0       2721

# %%
DATA[(DATA["favorites"] > 400)  & (DATA["retweets"] < 25)]
# Out:
#                                   full_text  favorites  retweets  mentions  \
# id
# 183722  Today we commemorate and MNML Case.      500.0      21.0       NaN
# 183735               Buy this product NOW!!      418.0      24.0       2.0
#
#        country             user  followers  followees
# id
# 183722  BRASIL    mateusmartins      982.0       1822
# 183735  MEXICO  gabrielcarvajal       21.0       2721

# %%
DATA[(DATA["followers"] > 500) & (DATA["country"] == "BRASIL")]
# Out:
#                                                 full_text  favorites  \
# id
# 183722                Today we commemorate and MNML Case.      500.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions country             user  followers  followees
# id
# 183722      21.0       NaN  BRASIL    mateusmartins      982.0       1822
# 183726      70.0       6.0  BRASIL    mateusmartins      982.0       1822
# 183730      92.0      29.0  BRASIL    mateusmartins      982.0       1822
# 183731     111.0       8.0  BRASIL    mateusmartins      982.0       1822
# 183732      44.0      19.0  BRASIL    mateusmartins      982.0       1822
# ...

# %%
DATA[(DATA["mentions"] < 10) & (DATA["user"] != "mateusmartins")]
# Out:
#                                                 full_text  favorites  \
# id
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183735                             Buy this product NOW!!      418.0
# 183736  I have one is best color gradients: Just relea...      361.0
# 183741                            Programming? i love it!       92.0
#
#         retweets  mentions  country             user  followers  followees
# id
# 183723     123.0       6.0   MEXICO      pedrojuarez       12.0        129
# 183724      76.0       3.0  ECUADOR     galocastillo      332.0        378
# 183725     130.0       9.0   MEXICO      pedrojuarez       12.0        129
# 183735      24.0       2.0   MEXICO  gabrielcarvajal       21.0       2721
# 183736      92.0       1.0   MEXICO      pedrojuarez       12.0        129
# ...

# %%
DATA[(DATA["followers"] > 100) & (DATA["mentions"] > 10)]
# Out:
#                                                 full_text  favorites  \
# id
# 183727                                 80's & friends! ✈️      158.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183732  Its been in love with the game with the origin...      349.0
# 183734                             I cannot believe this!       50.0
# 183742                                            WHAT???      255.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions  country             user  followers  followees
# id
# 183727      40.0      22.0  ECUADOR    leonardokuffo      389.0        258
# 183730      92.0      29.0   BRASIL    mateusmartins      982.0       1822
# 183732      44.0      19.0   BRASIL    mateusmartins      982.0       1822
# 183734      24.0      22.0  ECUADOR    leonardokuffo      389.0        258
# 183742      73.0      17.0  ECUADOR     galocastillo      332.0        378
# ...

# %%
DATA[DATA["followees"] > 1000]
# Out:
#                                                 full_text  favorites  \
# id
# 183722                Today we commemorate and MNML Case.      500.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183735                             Buy this product NOW!!      418.0
# 183738                             hmmm feeling bad today      296.0
# 183746                                           BORED AF      488.0
# 183747  I do not know if i like programming or other t...      318.0
#
#         retweets  mentions country             user  followers  followees
# id
# 183722      21.0       NaN  BRASIL    mateusmartins      982.0       1822
# 183726      70.0       6.0  BRASIL    mateusmartins      982.0       1822
# ...

# %%
DATA[(DATA["favorites"] < 500) & (DATA["followees"] < 600)]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183727                                 80's & friends! ✈️      158.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183733                           Programming is the best!      467.0
# 183734                             I cannot believe this!       50.0
# 183736  I have one is best color gradients: Just relea...      361.0
# 183737                                              PIC!!      346.0
# 183739                          not feeling god right now      315.0
# 183740                        Programming is a hot topic!      133.0
# ...

# %%
DATA[DATA["favorites"] < 500]
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# 183733                           Programming is the best!      467.0
# 183734                             I cannot believe this!       50.0
# ...

# %%
DATA[(DATA["full_text"].str.contains("Thanks")) & (DATA["favorites"] > 300)]
# Out:
#                                                 full_text  favorites  \
# id
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183744                                        Thanks man!      430.0
#
#         retweets  mentions country           user  followers  followees
# id
# 183726      70.0       6.0  BRASIL  mateusmartins      982.0       1822
# 183744     143.0      28.0  BRASIL     lucasperes        NaN        351

# %%
DATA

# %%
DATA.columns
# Out:
# Index(['full_text', 'favorites', 'retweets', 'mentions', 'country', 'user',
#        'followers', 'followees'],
#       dtype='object')

# %%
import random
def calcularGanancias(retweets):
    ganancia = retweets * random.randint(3, 5)
    return ganancia

DATA["Ganancias"] = DATA["retweets"].apply(calcularGanancias)

def popularidad(fila):
    resultado = fila["followees"]
    return resultado

DATA["popularidad"] = DATA.apply(popularidad, axis = 1)

DATA
# Out:
#                                                 full_text  favorites  \
# id
# 183721  Flying home to run down from the power to comi...       23.0
# 183722                Today we commemorate and MNML Case.      500.0
# 183723       Today we have reached US$6.55 Billion TT$44…      190.0
# 183724  Faking It by Joel Atwell. Written by Other cou...      131.0
# 183725                                    Welcome back! 🙌      113.0
# 183726  Contest: Win a fan of his ass. #thatisall Thanks!      492.0
# 183727                                 80's & friends! ✈️      158.0
# 183728  Thank you guess how did I feel somewhat offend...        NaN
# 183729        OnePlus 8 international giveaway classifies      198.0
# 183730                Here it is.. Retweet this desperate      272.0
# 183731  Great to advertise during the year I tweeted a...       43.0
# 183732  Its been in love with the game with the origin...      349.0
# ...
